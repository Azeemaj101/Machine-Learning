# %% [markdown]
# # Series in Pandas

# %%
import pandas as pd

# %%
lit = [1,2,3,"Azeem"]

# %%
ser = pd.Series(lit)
print(ser)
# Out:
# 0        1
# 1        2
# 2        3
# 3    Azeem
# dtype: object

# %%
ser[0]
# Out:
# 1

# %%
ser[2]
# Out:
# 3

# %%
ser[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser1 = pd.Series(lit)
print(ser1)
# Out:
# 0        1
# 1        2
# 2        3
# 3    Azeem
# dtype: object

# %%
ser + ser1
# Out:
# 0             2
# 1             4
# 2             6
# 3    AzeemAzeem
# dtype: object

# %%
ser2 = pd.Series(lit, index = ['a','b','c','d'])
print(ser2)
# Out:
# a        1
# b        2
# c        3
# d    Azeem
# dtype: object

# %%
ser + ser2
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# dtype: object

# %%
ser3 = pd.Series(['1','2','3','4'], index = ['a','b','c','d'], dtype = float)
print(ser3)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
dect_s = pd.Series({'a':1,'b':2})
dect_s
# Out:
# a    1
# b    2
# dtype: int64

# %%
max(ser3)
# Out:
# 4.0

# %%
min(ser3)
# Out:
# 1.0

# %% [markdown]
# # DataFrame

# %%
emp_df = pd.DataFrame([1,2,3])
emp_df
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dec = {"ID":[1,2,3,4]}
dec
# Out:
# {'ID': [1, 2, 3, 4]}

# %%
pd.DataFrame(dec)
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %%
dec1 = {"ID":pd.Series([1,2,3,4])}
dec1
# Out:
# {'ID': 0    1
#  1    2
#  2    3
#  3    4
#  dtype: int64}

# %%
pd.DataFrame(dec1)
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %% [markdown]
# # Read CSV

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv")
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1        No                          No                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
type(file)
# Out:
# pandas.core.frame.DataFrame

# %%
file.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %% [markdown]
# ## nrows, usecols, skiprows, index_col, header, prefix, names

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", nrows = 3)
file
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0   Yes                         Yes                  NaN       All industries
# 1    No                          No                   no       All industries
# 2  2020                     Level 1                  NaN       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  733,258  ANZSIC06 divisions A-S (excluding classes K633...
# 1  660,630  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", usecols = [0,2], nrows = 2)
file
# Out:
#   Year Industry_code_NZSIOC
# 0  Yes                  NaN
# 1   No                   no

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", skiprows = [2])
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1      2020                     Level 1                  NaN
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H05
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", skiprows = 2)
file
# Out:
#          No     No.1     no              All industries  Dollars (millions)  \
# 0      2020  Level 1    NaN              All industries  Dollars (millions)
# 1      2020  Level 1    NaN              All industries  Dollars (millions)
# 2      2020  Level 1    NaN              All industries  Dollars (millions)
# 3      2020  Level 1  99999              All industries  Dollars (millions)
# 4      2020  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 37073  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37074  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37075  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37076  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37077  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", skiprows = [2,3])
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1      2020                     Level 1                  NaN
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H07
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", skiprows = [2,3], index_col = 0)
file
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# Yes                          Yes                  NaN
# 2020                     Level 1                  NaN
# 2020                     Level 1                  NaN
# 2020                     Level 1                99999
# 2020                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# Yes               All industries  Dollars (millions)           H01
# 2020              All industries  Dollars (millions)           H07
# 2020              All industries  Dollars (millions)           H08
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", index_col = "Industry_aggregation_NZSIOC")
file
# Out:
#                              Year Industry_code_NZSIOC  \
# Industry_aggregation_NZSIOC
# Yes                           Yes                  NaN
# No                             No                   no
# Level 1                      2020                  NaN
# Level 1                      2020                  NaN
# Level 1                      2020                  NaN
# ...                           ...                  ...
# Level 3                      2013                 ZZ11
# Level 3                      2013                 ZZ11
# Level 3                      2013                 ZZ11
# Level 3                      2013                 ZZ11
# Level 3                      2013                 ZZ11
#
#                                    Industry_name_NZSIOC               Units  \
# Industry_aggregation_NZSIOC
# Yes                                      All industries  Dollars (millions)
# No                                       All industries  Dollars (millions)
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv")
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1        No                          No                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", header = [1])
file
# Out:
#         Yes    Yes.1 Unnamed: 2              All industries  \
# 0        No       No         no              All industries
# 1      2020  Level 1        NaN              All industries
# 2      2020  Level 1        NaN              All industries
# 3      2020  Level 1        NaN              All industries
# 4      2020  Level 1      99999              All industries
# ...     ...      ...        ...                         ...
# 37074  2013  Level 3       ZZ11  Food product manufacturing
# 37075  2013  Level 3       ZZ11  Food product manufacturing
# 37076  2013  Level 3       ZZ11  Food product manufacturing
# 37077  2013  Level 3       ZZ11  Food product manufacturing
# 37078  2013  Level 3       ZZ11  Food product manufacturing
#
#        Dollars (millions)  H01  \
# 0      Dollars (millions)  H04
# 1      Dollars (millions)  H05
# 2      Dollars (millions)  H07
# 3      Dollars (millions)  H08
# 4      Dollars (millions)  H09
# ...                   ...  ...
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", header = None)
file
# Out:
#           0                            1                     2  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1       Yes                          Yes                   NaN
# 2        No                           No                    no
# 3      2020                      Level 1                   NaN
# 4      2020                      Level 1                   NaN
# ...     ...                          ...                   ...
# 37076  2013                      Level 3                  ZZ11
# 37077  2013                      Level 3                  ZZ11
# 37078  2013                      Level 3                  ZZ11
# 37079  2013                      Level 3                  ZZ11
# 37080  2013                      Level 3                  ZZ11
#
#                                 3                   4              5  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", header = None, prefix="col-")
file
# Out:
#       col-0                        col-1                 col-2  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1       Yes                          Yes                   NaN
# 2        No                           No                    no
# 3      2020                      Level 1                   NaN
# 4      2020                      Level 1                   NaN
# ...     ...                          ...                   ...
# 37076  2013                      Level 3                  ZZ11
# 37077  2013                      Level 3                  ZZ11
# 37078  2013                      Level 3                  ZZ11
# 37079  2013                      Level 3                  ZZ11
# 37080  2013                      Level 3                  ZZ11
#
#                             col-3               col-4          col-5  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", usecols = [0,1,2], nrows = 2, names = ['a','b','c'])
file
# Out:
#       a                            b                     c
# 0  Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1   Yes                          Yes                   NaN

# %% [markdown]
# ## Head(), Tail(), dtype, true_values, false_values

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv")
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1        No                          No                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0   Yes                         Yes                  NaN       All industries
# 1    No                          No                   no       All industries
# 2  2020                     Level 1                  NaN       All industries
# 3  2020                     Level 1                  NaN       All industries
# 4  2020                     Level 1                  NaN       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
file.head(50)
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0    Yes                         Yes                  NaN
# 1     No                          No                   no
# 2   2020                     Level 1                  NaN
# 3   2020                     Level 1                  NaN
# 4   2020                     Level 1                  NaN
# 5   2020                     Level 1                99999
# 6   2020                     Level 1                99999
# 7   2020                     Level 1                99999
# 8   2020                     Level 1                99999
# 9   2020                     Level 1                99999
# 10  2020                     Level 1                99999
# 11  2020                     Level 1                99999
# 12  2020                     Level 1                99999
# 13  2020                     Level 1                99999
# 14  2020                     Level 1                99999
# ...

# %%
file.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37075  Food product manufacturing  Percentage           H37
# 37076  Food product manufacturing  Percentage           H38
# 37077  Food product manufacturing  Percentage           H39
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 37075                          Quick ratio  Financial ratios    52
# 37076  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
file.tail(50)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37030  2013                     Level 4                RS214
# 37031  2013                     Level 4                RS214
# 37032  2013                     Level 4                RS214
# 37033  2013                     Level 4                RS214
# 37034  2013                     Level 4                RS214
# 37035  2013                     Level 4                RS214
# 37036  2013                     Level 4                RS214
# 37037  2013                     Level 4                RS214
# 37038  2013                     Level 4                RS214
# 37039  2013                     Level 4                RS214
# 37040  2013                     Level 4                RS214
# 37041  2013                     Level 4                RS214
# 37042  2013                     Level 4                RS214
# 37043  2013                     Level 4                RS214
# ...

# %%
file1 = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", true_values=['Yes'])
file1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1        No                          No                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file1 = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", false_values=['No'])
file1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1        No                          No                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", dtype = {'Value': 'string'})
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1        No                          No                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", na_values='No')
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1       NaN                         NaN                   no
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", na_values=['No','no'])
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes                  NaN
# 1       NaN                         NaN                  NaN
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", keep_default_na = False)
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes
# 1        No                          No                   no
# 2      2020                     Level 1
# 3      2020                     Level 1
# 4      2020                     Level 1
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
file = pd.read_csv("CSV_Files//annual-enterprise-survey-2020-financial-year-provisional-csv.csv", na_filter=False)
file
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       Yes                         Yes
# 1        No                          No                   no
# 2      2020                     Level 1
# 3      2020                     Level 1
# 4      2020                     Level 1
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
file.isnull()
# Out:
#         Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      False                        False                 False
# 1      False                        False                 False
# 2      False                        False                 False
# 3      False                        False                 False
# 4      False                        False                 False
# ...      ...                          ...                   ...
# 37075  False                        False                 False
# 37076  False                        False                 False
# 37077  False                        False                 False
# 37078  False                        False                 False
# 37079  False                        False                 False
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                     False  False          False          False
# ...

# %%
file.isnull().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
file.isnull().sum().sum()
# Out:
# 0

# %%
file.notnull()
# Out:
#        Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      True                         True                  True
# 1      True                         True                  True
# 2      True                         True                  True
# 3      True                         True                  True
# 4      True                         True                  True
# ...     ...                          ...                   ...
# 37075  True                         True                  True
# 37076  True                         True                  True
# 37077  True                         True                  True
# 37078  True                         True                  True
# 37079  True                         True                  True
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                      True   True           True           True
# 1                      True   True           True           True
# ...

# %%
file.notnull().sum()
# Out:
# Year                           37080
# Industry_aggregation_NZSIOC    37080
# Industry_code_NZSIOC           37080
# Industry_name_NZSIOC           37080
# Units                          37080
# Variable_code                  37080
# Variable_name                  37080
# Variable_category              37080
# Value                          37080
# Industry_code_ANZSIC06         37080
# dtype: int64

# %%
file.notnull().sum().sum()
# Out:
# 370800

# %%
file1 = pd.read_csv("CSV_Files//Azeem1.csv")
file1
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 3  moazam      7       i         i         i         i         i       NaN
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 3         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(axis=0)
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(axis=1)
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.6
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 3  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i

# %%
file1.dropna(axis=0, how="any") #if one NaN in column or row so any remove all row or column
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(axis=1, how="any") #if one NaN in column or row so any remove all row or column
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.6
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 3  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i

# %%
file1.dropna(axis=0, how="all") #if All NaN in column or row so any remove all row or column
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 3  moazam      7       i         i         i         i         i       NaN
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 3         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(axis=1, how="any") #if one NaN in column or row so any remove all row or column
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.6
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 3  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i

# %%
file1.dropna(thresh =8) #accept 8 non NaN values
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 3  moazam      7       i         i         i         i         i       NaN
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 3         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(thresh =9) #accept 9 non NaN values
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(subset = ['section.5']) # Remove column if it contain NaN
# Out:
#      Name  Class section section.1 section.2 section.3 section.4 section.5  \
# 0   Azeem      5       g         g         g         g         g         g
# 1  moazma      6       f         f         f         f         f         f
# 2  moazam      7       i         i         i         i         i         i
# 4  moazam      7       i         i         i         i         i         i
# 5  moazam      7       i         i         i         i         i         i
# 6  moazam      7       i         i         i         i         i         i
# 7  moazam      7       i         i         i         i         i         i
#
#   section.6
# 0         g
# 1         f
# 2         i
# 4         i
# 5         i
# 6         i
# 7         i

# %%
file1.dropna(inplace = True) # Change in Real Variable
